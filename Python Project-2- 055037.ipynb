# %% [markdown]
# # Project Information
#
# **Project Title:** Data Exploration with Python.
#
# **Students Name:**
# Devansh Pratap Singh (055037)
#
# **Course:** BDA(05), Section K

# %% [markdown]
# # 1. Description of Data:
# The dataset contains transactional and categorical data, potentially covering multiple countries, product categories, and transaction values. The key variables used in this analysis include:
#
# - **Country:** A categorical variable representing different geographical locations.
# - **Transaction Value:** A continuous variable indicating the monetary value of each transaction.
# - **Product Category:** A categorical variable identifying various product types.
#
# This data allows for statistical analysis to identify relationships between countries, product categories, and transaction values, providing insights into customer behavior and economic performance across regions.
#
# # 2. Project Objectives and Problem Statement:
# The objectives and problem statements for this project are as follows:
#
# - **Objective 1:** Analyze whether there are significant differences in transaction values across different countries.
#   - **Problem Statement:** Do the average transaction values vary between countries? (Tested using t-tests or ANOVA).
#
# - **Objective 2:** Investigate the association between countries and product categories to uncover regional product preferences.
#   - **Problem Statement:** Is there a significant relationship between countries and product categories? (Analyzed using the Chi-Square test).
#
# - **Objective 3:** Examine correlations between continuous variables, such as transaction value and other numerical factors (if applicable).
#   - **Problem Statement:** Are there any strong relationships between numerical variables that explain transaction value trends? (Analyzed using Pearson or Spearman correlation tests).
#
# # 3. Analysis of Data:
# To address these objectives, various statistical tests are performed, each with specific goals:
#
# ### Two-Sample Independent t-Test:
# - Compares the means of transaction values between two countries.
# - **Null hypothesis (H₀):** The means of transaction values between the two countries are equal.
# - **Alternative hypothesis (H₁):** The means of transaction values differ.
# - A significant p-value (< 0.05) indicates a difference between the two countries.
#
# ### Analysis of Variance (ANOVA):
# - Used when comparing transaction values across more than two countries.
# - **Null hypothesis (H₀):** All countries have the same mean transaction value.
# - **Alternative hypothesis (H₁):** At least one country has a different mean.
# - Post-hoc tests (e.g., Tukey's HSD) can be used to identify which countries differ.
#
# ### Chi-Square Test of Independence:
# - Tests for an association between two categorical variables, such as country and product category.
# - **Null hypothesis (H₀):** Country and product category are independent.
# - **Alternative hypothesis (H₁):** There is a significant association between country and product category.
#
# ### Correlation Analysis:
# - Examines the relationship between two continuous variables (e.g., transaction value and time).
# - **Pearson Correlation:** Measures linear relationships.
# - **Spearman Correlation:** Measures monotonic relationships (non-linear trends).
#
# ### Regression Analysis (Optional):
# - If multiple predictors (e.g., product type, country) are available, a regression model can be built to predict transaction value.
# - **Multiple Linear Regression:** Helps quantify how each factor influences transaction value.
#
# # 4. Observations and Findings:
# The results from statistical tests yield several important insights:
#
# - **T-Test Findings:** A significant t-test result indicates that transaction values vary significantly between two countries. This could highlight differences in purchasing power or regional economic conditions.
# - **ANOVA Findings:** If the ANOVA result is significant, it shows that not all countries have the same average transaction value. Post-hoc tests can identify which countries stand out.
# - **Chi-Square Findings:** A significant Chi-Square result indicates that product categories and countries are associated, revealing regional preferences for certain products.
# - **Correlation Findings:** Significant correlations between transaction values and other continuous variables suggest possible predictors of transaction behavior, such as time or quantity.
# - **Regression Findings (if applicable):** A well-fitting regression model helps predict future transaction values based on variables like country and product category, aiding strategic decision-making.
#
# # 5. Managerial Insights and Recommendations:
# Based on the analysis, here are six key managerial insights and four strategic recommendations:
#
# ## Managerial Insights:
# 1. **Regional Performance Variability:** Countries with higher transaction values could represent regions with greater purchasing power or more established markets. These areas present opportunities for resource allocation and business expansion.
#
# 2. **Product Preferences Across Regions:** The association between countries and product categories indicates that certain products are more popular in specific regions. Businesses can optimize their inventory and marketing strategies accordingly.
#
# 3. **Transaction Value Trends:** Significant correlations between transaction value and other factors (e.g., time of purchase or product type) suggest that sales strategies can be fine-tuned to target peak purchasing periods or higher-value products.
#
# 4. **Differences in Customer Behavior:** Variation in transaction values across countries implies that customer behavior, preferences, or economic conditions differ by region. Understanding these differences can inform targeted marketing and pricing strategies.
#
# 5. **Profitability Forecasting:** A regression model that accurately predicts transaction values based on variables such as country, product type, and demographics can be used to forecast future sales, allowing for better financial planning and resource allocation.
#
# 6. **Maximizing ROI:** By identifying the regions and product categories with the highest transaction values, businesses can focus their efforts on areas that promise the greatest return on investment.
#
# ## Recommendations:
# 1. **Focus on High-Performing Regions:** Allocate marketing and operational resources to countries or regions with the highest transaction values. These markets offer the greatest potential for revenue growth.
#
# 2. **Tailor Product Offerings:** Customize product assortments for specific regions based on the analysis of regional preferences. This will increase customer satisfaction and drive higher sales by aligning offerings with local demand.
#
# 3. **Leverage Seasonal and Temporal Insights:** If transaction values peak during certain times or seasons, launch targeted promotions or increase stock during these periods to maximize sales.
#
# 4. **Address Underperforming Regions:** For countries with lower transaction values, investigate the underlying causes (e.g., economic factors or lack of customer awareness) and adjust strategies such as pricing, marketing, or product availability to improve performance.

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# A1. Load the Test Data.
data=pd.read_csv("C://Users/Devansh/Downloads/Imports_Exports_Dataset.csv")
data
# A3. Create an Unique Sample of 2001 Records using Student Roll Number as Random State.
data1=data.sample(n=3001,random_state=55037)
data1
# Out:
#                              Transaction_ID                           Country  \
# 13113  cfe5d7ee-b8e7-46a2-925a-9ee21ef14c5b  Lao People's Democratic Republic
# 5490   582a4042-8d62-40ae-b601-02146273633d                           Vietnam
# 4248   958ef526-841a-4762-a0d5-e8218327f24c                            Serbia
# 14026  7f98e33e-4156-403c-982e-a385226dd7a2                         Indonesia
# 11704  26f0b080-f883-4041-a065-ef9ee1dc212e                          Maldives
# ...                                     ...                               ...
# 2233   d52583c8-4ceb-46d3-9fe6-2e363162ef95                          Portugal
# 9735   ef523332-c690-43d7-b4ac-bc7e707bd474                  Saint Barthelemy
# 3344   ab2d8221-fbf7-4de9-a20f-e45525453a55                            Taiwan
# 11921  59163d7f-3907-4435-a080-6ab0b15abcad                             Gabon
# 12371  2b2f3e9c-cc24-48e6-ad2c-93d9bc810e3f                            Turkey
#
# ...

# %%
# Display summary statistics for numerical columns
data.describe()
# Out:
#            Quantity         Value  Customs_Code        Weight  Invoice_Number
# count  15000.000000  15000.000000   15000.00000  15000.000000    1.500000e+04
# mean    4980.554733   5032.931120  549507.95920   2492.118859    5.020677e+07
# std     2866.166690   2857.593897  260886.91886   1451.378507    2.889888e+07
# min        1.000000    102.120000  100041.00000      0.570000    4.202600e+04
# 25%     2517.000000   2552.750000  325635.50000   1243.482500    2.527742e+07
# 50%     4958.500000   5045.705000  545432.00000   2476.135000    5.026745e+07
# 75%     7458.250000   7504.700000  777988.00000   3747.392500    7.510045e+07
# max    10000.000000   9999.130000  999964.00000   4999.930000    9.999799e+07

# %%
# Count the number of transactions for each country
country_counts = data1['Country'].value_counts()
country_counts.head(10)  # Top 10 countries
# Out:
# Congo            30
# Austria          29
# New Zealand      25
# Grenada          23
# Canada           23
# Guinea-Bissau    23
# Morocco          22
# Poland           21
# Burundi          21
# Algeria          21
# Name: Country, dtype: int64

# %%
# Count the frequency of products
product_counts = data1['Product'].value_counts()
product_counts.head(10)  # Top 10 products
# Out:
# floor        11
# in           10
# card          9
# local         9
# her           9
# sometimes     9
# agreement     8
# challenge     8
# indeed        8
# probably      8
# Name: Product, dtype: int64

# %%
# Convert Date column to datetime
data1['Date'] = pd.to_datetime(data1['Date'], format='%d-%m-%Y')

# Group by year and month and sum the total transaction values
monthly_trends = data1.groupby(data1['Date'].dt.to_period('M'))['Value'].sum()

# Plotting (if needed)
import matplotlib.pyplot as plt
monthly_trends.plot(kind='line', figsize=(10, 6), title='Transaction Value Over Time')
plt.xlabel('Month')
plt.ylabel('Total Value')
plt.show()

# %%
# Group by Import/Export and sum the total values
import_export_comparison = data1.groupby('Import_Export')['Value'].sum()

# Plotting
import_export_comparison.plot(kind='bar', title='Total Value of Imports vs Exports')
plt.xlabel('Transaction Type')
plt.ylabel('Total Value')
plt.show()

# %%
# Central Tendency (Mean, Median, Mode)
mean_val = data1['Value'].mean()
median_val = data1['Value'].median()
mode_val = data1['Value'].mode()

# Measures of Dispersion (Range, Standard Deviation)
range_val = data1['Value'].max() - data1['Value'].min()
std_dev = data1['Value'].std()

# Summary of the non-categorical columns
summary_stats = data1.describe()

print("Mean:", mean_val)
print("Median:", median_val)
print("Mode:", mode_val)
print("Range:", range_val)
print("Standard Deviation:", std_dev)
print("Summary Statistics:\n", summary_stats)
# Out:
# Mean: 5083.446207930682
# Median: 5146.0
# Mode: 0    1160.99
# 1    5592.90
# 2    7009.52
# Name: Value, dtype: float64
# Range: 9881.460000000001
# Standard Deviation: 2818.769163610664
# Summary Statistics:
#            Quantity        Value   Customs_Code       Weight  Invoice_Number
# count  3001.000000  3001.000000    3001.000000  3001.000000    3.001000e+03
# mean   4909.159280  5083.446208  547214.360546  2497.459760    5.034708e+07
# std    2833.830622  2818.769164  261796.682832  1461.393785    2.911960e+07
# min       9.000000   106.150000  100171.000000     2.800000    4.795400e+04
# 25%    2469.000000  2694.010000  318544.000000  1241.350000    2.486596e+07
# 50%    4852.000000  5146.000000  542073.000000  2472.850000    5.087155e+07
# 75%    7310.000000  7518.450000  774458.000000  3763.350000    7.542723e+07
# max    9995.000000  9987.610000  999752.000000  4999.520000    9.997707e+07

# %%
# Frequency of categorical data
country_counts = data1['Country'].value_counts()
product_counts = data1['Product'].value_counts()

print("Top Countries:\n", country_counts.head())
print("Top Products:\n", product_counts.head())
# Out:
# Top Countries:
#  Congo          30
# Austria        29
# New Zealand    25
# Grenada        23
# Canada         23
# Name: Country, dtype: int64
# Top Products:
#  floor    11
# in       10
# card      9
# local     9
# her       9
# Name: Product, dtype: int64

# %%
# Group by Import_Export and perform ANOVA
anova_result = stats.f_oneway(data1[data1['Import_Export'] == 'Import']['Value'],
                              data1[data1['Import_Export'] == 'Export']['Value'])

print("ANOVA Result:\n", anova_result)
# Out:
# ANOVA Result:
#  F_onewayResult(statistic=0.1534853180370484, pvalue=0.6952545038782427)

# %%
# Crosstab for Chi-square test between Country and Import_Export
country_import_export_crosstab = pd.crosstab(data1['Country'], data1['Import_Export'])
chi2_stat, p_val, dof, expected = stats.chi2_contingency(country_import_export_crosstab)

print("Chi-Square Statistic:", chi2_stat)
print("P-Value:", p_val)
# Out:
# Chi-Square Statistic: 243.6472049642404
# P-Value: 0.45818963182933364

# %%
# Select features and target for linear regression
X = data1[['Quantity', 'Weight']]  # Features
y = data1['Value']  # Target

# Create linear regression model
model = LinearRegression()
model.fit(X, y)

# Display model coefficients
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 5050.641536915591
# Coefficients: [-0.00837469  0.02959701]

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
# Convert categorical 'Import_Export' into numerical values for logistic regression
data1['Import_Export_Num'] = data1['Import_Export'].apply(lambda x: 1 if x == 'Export' else 0)

# Select features and target for logistic regression
X_log = data1[['Quantity', 'Weight', 'Value']]
y_log = data1['Import_Export_Num']

# Logistic regression model
logit_model = sm.Logit(y_log, sm.add_constant(X_log)).fit()

# Print logistic regression summary
print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692978
#          Iterations 3
#                            Logit Regression Results
# ...
# Dep. Variable:      Import_Export_Num   No. Observations:                 3001
# Model:                          Logit   Df Residuals:                     2997
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 14 Oct 2024   Pseudo R-squ.:               0.0001761
# Time:                        10:30:57   Log-Likelihood:                -2079.6
# converged:                       True   LL-Null:                       -2080.0
# Covariance Type:            nonrobust   LLR p-value:                    0.8656
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0545      0.115      0.474      0.636      -0.171       0.280
# ...

# %%
# Import Relevant Python Libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
# Bar Plot for country frequency
plt.figure(figsize=(10, 6))
sns.countplot(y='Country', data=data1, order=data1['Country'].value_counts().index)
plt.title('Number of Transactions per Country')
plt.show()

# Pie chart for Import/Export distribution
import_export_counts = data1['Import_Export'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(import_export_counts, labels=import_export_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Import vs Export Distribution')
plt.show()

# %%
print(data1.columns)
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms', 'Import_Export_Num'],
#       dtype='object')

# %%
# Display basic information about the dataset
file_path = ("C://Users/Devansh/Downloads/Imports_Exports_Dataset.csv")

data = pd.read_csv(file_path)

print("Dataset Information:")
data.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
import pandas as pd
from scipy import stats

# Load your dataset
import pandas as pd
from scipy import stats

# Load your dataset
import pandas as pd
from scipy import stats

# Load your dataset
data=pd.read_csv("C://Users/Devansh/Downloads/Imports_Exports_Dataset.csv")
data

# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with your actual column names)
if 'Country' in data.columns and 'transaction_value' in data.columns:
    
    # Get unique values of the 'Country' column to split into groups (assuming 'Country' is the categorical column)
    unique_countries = data['Country'].unique()
    print(f"Unique Countries in the dataset: {unique_countries}")
    
    # Filter the dataset for two countries (assuming we want to compare 'CountryA' and 'CountryB')
    group_A = data[data['Country'] == unique_countries[0]]['transaction_value'].dropna()
    group_B = data[data['Country'] == unique_countries[1]]['transaction_value'].dropna()

    # Perform two-sample independent t-test
    t_statistic, p_value = stats.ttest_ind(group_A, group_B)

    # Print the t-test result
    print("\nTwo-Sample t-test (Independent Groups):")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")

    # Interpretation of results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: The means of the two groups are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the means of the two groups.")

else:
    print("The required columns 'Country' and 'transaction_value' are not found in the dataset.")


# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with your actual column names)
if 'Country' in data.columns and 'transaction_value' in data.columns:
    
    # Get unique values of the 'Country' column to split into groups (assuming 'Country' is the categorical column)
    unique_countries = data['Country'].unique()
    print(f"Unique Countries in the dataset: {unique_countries}")
    
    # Filter the dataset for two countries (assuming we want to compare 'CountryA' and 'CountryB')
    group_A = data[data['Country'] == unique_countries[0]]['transaction_value'].dropna()
    group_B = data[data['Country'] == unique_countries[1]]['transaction_value'].dropna()

    # Perform two-sample independent t-test
    t_statistic, p_value = stats.ttest_ind(group_A, group_B)

    # Print the t-test result
    print("\nTwo-Sample t-test (Independent Groups):")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")

    # Interpretation of results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: The means of the two groups are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the means of the two groups.")

else:
    print("The required columns 'Country' and 'transaction_value' are not found in the dataset.")


# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with your actual column names)
if 'Country' in data.columns and 'transaction_value' in data.columns:
    
    # Get unique values of the 'Country' column to split into groups (assuming 'Country' is the categorical column)
    unique_countries = data['Country'].unique()
    print(f"Unique Countries in the dataset: {unique_countries}")
    
    # Filter the dataset for two countries (assuming we want to compare 'CountryA' and 'CountryB')
    group_A = data[data['Country'] == unique_countries[0]]['transaction_value'].dropna()
    group_B = data[data['Country'] == unique_countries[1]]['transaction_value'].dropna()

    # Perform two-sample independent t-test
    t_statistic, p_value = stats.ttest_ind(group_A, group_B)

    # Print the t-test result
    print("\nTwo-Sample t-test (Independent Groups):")
    print(f"T-statistic: {t_statistic}")
    print(f"P-value: {p_value}")

    # Interpretation of results
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: The means of the two groups are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the means of the two groups.")

else:
    print("The required columns 'Country' and 'transaction_value' are not found in the dataset.")
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Python Code for Chi-Square Test:

# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with actual column names)
if 'Country' in data.columns and 'Product_Category' in data.columns:
    
    # Create a contingency table (cross-tabulation) of the two categorical variables
    contingency_table = pd.crosstab(data['Country'], data['Product_Category'])

    # Perform the Chi-Square test
    chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

    # Print the results
    print("\nChi-Square Test Results:")
    print(f"Chi-Square Statistic: {chi2_stat}")
    print(f"P-value: {p_value}")
    print(f"Degrees of Freedom: {dof}")
    print(f"Expected Frequencies Table:\n{expected}")

    # Interpretation of the p-value
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant association between 'Country' and 'Product_Category'.")
    else:
        print("Fail to reject the null hypothesis: No significant association between 'Country' and 'Product_Category'.")

else:
    print("The required columns 'Country' and 'Product_Category' are not found in the dataset.")
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Python Code for F-test (ANOVA):

# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with your actual column names)
if 'Country' in data.columns and 'transaction_value' in data.columns:
    
    # Get unique values of the 'Country' column (assuming 'Country' is a categorical variable)
    unique_countries = data['Country'].unique()
    print(f"Unique Countries in the dataset: {unique_countries}")

    # Create a list of groups based on '
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Shapiro-Wilk Test:
# Display first few rows to inspect the dataset
print(data.head())

# Perform Shapiro-Wilk Test on 'transaction_value' (replace with your actual column name)
if 'transaction_value' in data.columns:
    shapiro_stat, shapiro_p_value = stats.shapiro(data['transaction_value'].dropna())

    print("\nShapiro-Wilk Test for Normality:")
    print(f"Shapiro-Wilk Statistic: {shapiro_stat}")
    print(f"P-value: {shapiro_p_value}")

    # Interpretation of the p-value
    alpha = 0.05  # significance level
    if shapiro_p_value > alpha:
        print("Fail to reject the null hypothesis: The data follows a normal distribution.")
    else:
        print("Reject the null hypothesis: The data does not follow a normal distribution.")
else:
    print("The column 'transaction_value' is not found in the dataset.")
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Kolmogorov-Smirnov Test:

# Display first few rows to inspect the dataset
print(data.head())

# Perform Kolmogorov-Smirnov Test on 'transaction_value' (replace with your actual column name)
if 'transaction_value' in data.columns:
    ks_stat, ks_p_value = stats.kstest(data['transaction_value'].dropna(), 'norm')

    print("\nKolmogorov-Smirnov Test for Normality:")
    print(f"KS Statistic: {ks_stat}")
    print(f"P-value: {ks_p_value}")

    # Interpretation of the p-value
    alpha = 0.05  # significance level
    if ks_p_value > alpha:
        print("Fail to reject the null hypothesis: The data follows a normal distribution.")
    else:
        print("Reject the null hypothesis: The data does not follow a normal distribution.")
else:
    print("The column 'transaction_value' is not found in the dataset.")
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
#Python Code for Chi-Square Test on Categorical Data:
# Display first few rows to inspect the dataset
print(data.head())

# Check if the necessary columns exist (replace with actual column names)
if 'Country' in data.columns and 'Product_Category' in data.columns:
    
    # Create a contingency table (cross-tabulation) of the two categorical variables
    contingency_table = pd.crosstab(data['Country'], data['Product_Category'])

    # Perform the Chi-Square test
    chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)

    # Print the results
    print("\nChi-Square Test Results:")
    print(f"Chi-Square Statistic: {chi2_stat}")
    print(f"P-value: {p_value}")
    print(f"Degrees of Freedom: {dof}")
    print(f"Expected Frequencies Table:\n{expected}")

    # Interpretation of the p-value
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant association between 'Country' and 'Product_Category'.")
    else:
        print("Fail to reject the null hypothesis: No significant association between 'Country' and 'Product_Category'.")

else:
    print("The required columns 'Country' and 'Product_Category' are not found in the dataset.")
# Out:
#                          Transaction_ID           Country    Product  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd          Colombia   describe
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455             Chile  president
# 2  eb1167b3-67a9-4378-bc65-c1e582e2e662            Turkey        far
# 3  f7c1bd87-4da5-4709-9471-3d60c8a70639  Christmas Island     agency
# 4  e443df78-9558-467f-9ba9-1faf7a024204           Finland     policy
#
#   Import_Export  Quantity    Value        Date     Category              Port  \
# 0        Export      1979  9506.57  07-12-2023    Machinery        Robertbury
# 1        Export      5763  7100.91  04-04-2023     Clothing          Shahport
# 2        Import      5740  2450.34  21-08-2024  Electronics  South Joshuatown
# 3        Export      2592  7226.42  09-05-2022    Furniture          Adamfort
# 4        Export      2622  2817.29  03-04-2023  Electronics         Juliebury
#
#    Customs_Code   Weight Shipping_Method                         Supplier  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Visualization 1: Top 10 Countries by Quantity of Imports/Exports
top_countries = data.groupby('Country')['Quantity'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries by Quantity of Imports/Exports')
plt.xlabel('Country')
plt.ylabel('Total Quantity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Visualization 2: Distribution of Import/Export Value by Category
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Category', y='Value')
plt.title('Distribution of Import/Export Value by Category')
plt.xlabel('Category')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Visualization 3: Total Weight by Shipping Method
shipping_method_weights = data.groupby('Shipping_Method')['Weight'].sum()
plt.figure(figsize=(8, 5))
shipping_method_weights.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Total Weight by Shipping Method')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
# Visualization 4: Count of Transactions per Import/Export Type
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='Import_Export', palette='viridis')
plt.title('Count of Transactions per Import/Export Type')
plt.xlabel('Import/Export')
plt.ylabel('Number of Transactions')
plt.tight_layout()
plt.show()

# %%
# Visualization 5: Average Transaction Value by Payment Terms
avg_value_payment_terms = data.groupby('Payment_Terms')['Value'].mean()
plt.figure(figsize=(10, 6))
avg_value_payment_terms.plot(kind='bar', color='salmon')
plt.title('Average Transaction Value by Payment Terms')
plt.xlabel('Payment Terms')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
